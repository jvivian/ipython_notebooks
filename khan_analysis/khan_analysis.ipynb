# %% [markdown]
# Collate Dataframe of Neuroblastoma KHAN set

# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
khan_set = pd.read_table('NCI-KHAN-Neuroblastoma.tsv', sep='\t')
clinical_table = pd.read_table('TARGET_clinical_data.csv', sep=',')
clinical_table=clinical_table.rename(columns = {'TARGUSI':'subject_id'})
df = pd.DataFrame()

# %%
khan_set.head()
# Out:
#   Assay_Type    AssemblyName     BioSample Center_Name Experiment  InsertSize  \
# 0    RNA-Seq          GRCh37  SAMN00116525     BCCAGSC  SRX029463           0
# 1    RNA-Seq  <not provided>  SAMN00116525    NCI-KHAN  SRX687713         200
# 2    RNA-Seq          GRCh37  SAMN00116529     BCCAGSC  SRX029465           0
# 3    RNA-Seq  <not provided>  SAMN00116529    NCI-KHAN  SRX687604         200
# 4    RNA-Seq          GRCh37  SAMN00116533     BCCAGSC  SRX029467           0
#
#   LibrarySelection   LibrarySource   Library_Name      LoadDate  \
# 0             cDNA  TRANSCRIPTOMIC         HS1795  May 28, 2012
# 1            other  TRANSCRIPTOMIC  NB2323tumor_T  Sep 19, 2014
# 2             cDNA  TRANSCRIPTOMIC         HS1797  May 26, 2012
# 3            other  TRANSCRIPTOMIC  NB2067tumor_T  Sep 19, 2014
# 4             cDNA  TRANSCRIPTOMIC         HS1799  May 28, 2012
#
#          ...         SRA_Study  g1k_analysis_group    g1k_pop_code  \
# ...

# %%
clinical_table.head()
# Out:
#          subject_id  Gender     Race               Ethnicity  \
# 0  TARGET-30-PAAPFA    Male    White  Not Hispanic or Latino
# 1  TARGET-30-PACLJN    Male    White  Not Hispanic or Latino
# 2  TARGET-30-PACPJG  Female    White  Not Hispanic or Latino
# 3  TARGET-30-PACRYY    Male  Unknown      Hispanic or Latino
# 4  TARGET-30-PACRZM    Male    White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      1762       Event                               444
# 1                      1475    Censored                              5553
# 2                       760     Unknown                               NaN
# 3                      1314    Censored                              5296
# 4                      3686       Event                               922
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0         Dead                            487               1986
# ...

# %%
df['run'] = khan_set['Run']
df['library'] = khan_set['Library_Name']
df['MBases'] = khan_set['MBases']
df['subject_id'] = khan_set['submitted_subject_id']

# %%
df.head()
# Out:
#           run        library  MBases        subject_id
# 0   SRR391609         HS1795   12895  TARGET-30-PANNMS
# 1  SRR1559184  NB2323tumor_T    9328  TARGET-30-PANNMS
# 2   SRR391610         HS1797   12884  TARGET-30-PANRRW
# 3  SRR1559076  NB2067tumor_T   21363  TARGET-30-PANRRW
# 4   SRR391611         HS1799   13241  TARGET-30-PANYGR

# %%
clinical_table[clinical_table['TARGUSI'].isin(df.loc[[0]]['subject_id'])]
# Out:
#               TARGUSI  Gender   Race               Ethnicity  \
# 414  TARGET-30-PANNMS  Female  White  Not Hispanic or Latino
#
#      Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 414                      1080    Censored                              3509
#
#     Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 414        Alive                           3509               2005
#
#                   ...                  ICDO COG Risk Group Percent Tumor  \
# 414               ...                 C48.0      High Risk         90-95
#
#     Percent Necrosis Percent Tumor v/s Stroma  Sites of Disease Involvement  \
# 414                5                      NaN                           NaN
#
#     Site of Relapse Relapse Percent Tumor Relapse Percent Necrosis  \
# 414             NaN                   NaN                      NaN
#
#     Relapse Percent Tumor v/s Stroma
# 414                              NaN
#
# [1 rows x 30 columns]

# %%
test = pd.concat
